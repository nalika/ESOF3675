# %% [markdown]
# <a href="https://colab.research.google.com/github/nalika/ESOF3675/blob/main/Lab_7_Apriori_Algorithm_for_Association_Rule_Mining_(Blank).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fill the information below. Also, share your notebook to everyone with the link. It could be with everyone under Lakehead that have the link.

# %% [markdown]
# **Student Name:** (First_Name) (Last_Name)
#
# **Student ID:** (XXXXXXXXXX)
#
# **Lab No.:** 7
#
# **Colab link:**

# %% [markdown]
# # Lab 7 Annoucement
#
# In this lab you will work with
#   - [MLxtend Package](https://rasbt.github.io/mlxtend/)
#   - [Apriori Algorithm](https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/)
#   - [Association Rules](https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/)

# %% [markdown]
# # Notebook Configuration

# %%
# !pip install -U mlxtend plotly
# Out:
# Requirement already up-to-date: mlxtend in /usr/local/lib/python3.7/dist-packages (0.18.0)
# ...
#      |████████████████████████████████| 13.2MB 251kB/s
# ...
#   Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# ...

# %%
import mlxtend

# %%
mlxtend.__version__
# Out:
# '0.18.0'

# %%
import numpy as np
import pandas as pd

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
np.set_printoptions(linewidth=240)

# %% [markdown]
# # Data Sample

# %% [markdown]
# Consider the data below, in which we have list of transactions. Each transaction is given as a set of elements.

# %%
dataset_sample = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
                  ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
                  ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
                  ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
                  ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %% [markdown]
# ## Task 1: Data Investigation

# %% [markdown]
# Create a `tuple` of unique items in the `dataset_sample`. Then use this `tuple` to find out how many unique items there are in the `dataset_sample`.

# %%
# Warm up task

all_items_sample = set()
# Code in here
print(f'Total Unique Items in dataset_sample: {len(all_items_sample)}')
# Out:
# Total Unique Items in dataset_sample: 11

# %% [markdown]
# ## Task 2: Data Pre-processing

# %% [markdown]
# In order to use the `apriori` we first need to encode the data. The allowed values are either 0/1 or True/False.

# %% [markdown]
# **Task 2a**: Instanciate the `TransactionEncoder`

# %%
encoder = # Add your code here
print(encoder.columns_)
# Out:
# ['Apple', 'Corn', 'Dill', 'Eggs', 'Ice cream', 'Kidney Beans', 'Milk', 'Nutmeg', 'Onion', 'Unicorn', 'Yogurt']

# %% [markdown]
# **Task 2b**: Use the `encoder` to `transform` the dataset of transaction.

# %%
sample_encoded = encoder.# Add your code here
sample_encoded
# Out:
# array([[False, False, False,  True, False,  True,  True,  True,  True, False,  True],
#        [False, False,  True,  True, False,  True, False,  True,  True, False,  True],
#        [ True, False, False,  True, False,  True,  True, False, False, False, False],
#        [False,  True, False, False, False,  True,  True, False, False,  True,  True],
#        [False,  True, False,  True,  True,  True, False, False,  True, False, False]])

# %% [markdown]
# **Task 2c**: Now, create a `pandas`' `Dataframe` with this information.

# %%
df_sample = # Add your code here
df_sample
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  ...   Milk  Nutmeg  Onion  Unicorn  Yogurt
# 0  False  False  False   True      False  ...   True    True   True    False    True
# 1  False  False   True   True      False  ...  False    True   True    False    True
# 2   True  False  False   True      False  ...   True   False  False    False   False
# 3  False   True  False  False      False  ...   True   False  False     True    True
# 4  False   True  False   True       True  ...  False   False   True    False   False
#
# [5 rows x 11 columns]

# %%
print(f'Number of entries: {len(df_sample)}')
print(f'Number of items: {len(df_sample.columns)}')
print(f'Items are: {list(df_sample.columns)}')
# Out:
# Number of entries: 5
# Number of items: 11
# Items are: ['Apple', 'Corn', 'Dill', 'Eggs', 'Ice cream', 'Kidney Beans', 'Milk', 'Nutmeg', 'Onion', 'Unicorn', 'Yogurt']

# %% [markdown]
# # Building Model

# %% [markdown]
# ## The Apriori Algorithm

# %% [markdown]
# [![image.png](data:image/png;base64,...)](https://www.slideshare.net/wolverine1309/rmining)

# %% [markdown]
# ## Task 3: Listing Frequent Itemsets

# %% [markdown]
# **Task 3a**: Use the `apriori` function to list the itemsets.

# %%
# Add your code here
# Out:
#     support   itemsets
# 0       0.8        (3)
# 1       1.0        (5)
# 2       0.6        (6)
# 3       0.6        (8)
# 4       0.6       (10)
# 5       0.8     (3, 5)
# 6       0.6     (8, 3)
# 7       0.6     (5, 6)
# 8       0.6     (8, 5)
# 9       0.6    (10, 5)
# 10      0.6  (8, 3, 5)

# %% [markdown]
# **Task 3b**: Use the `apriori` function to list **all** itemsets of size `1`. Sort the results in descending order by the `support` value.
#
# Tip: Check the [documentation for this function](https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/#api). You will need to set three arguments `min_support`, `use_colnames` and `max_len`.
#
# Tip: To include all frequent itemsets, ensure to provide a `min_support` small enough, approaching zero.

# %%
df_itemset_max_1 = # Add your code here
df_itemset_max_1 = # Add your code here for sorting the dataframe.
display(df_itemset_max_1.head(10))
print(f'\nNumber of Itemsets: {len(df_itemset_max_1)}')
# Out:
#    support        itemsets
# 0      1.0  (Kidney Beans)
# 1      0.8          (Eggs)
# 2      0.6          (Milk)
# 3      0.6         (Onion)
# 4      0.6        (Yogurt)
# 5      0.4          (Corn)
# 6      0.4        (Nutmeg)
# 7      0.2         (Apple)
# 8      0.2          (Dill)
# 9      0.2     (Ice cream)
# Number of Itemsets: 11

# %% [markdown]
# **Task 3c**: Use the `apriori` function to list all itemsets up to size `2`. Sort the results in descending order by the `support` value.

# %%
df_itemset_max_2 = # Add your code here
df_itemset_max_2 = # Add your code here for sorting the dataframe
display(df_itemset_max_2.head(10))
print(f'\nNumber of Itemsets: {len(df_itemset_max_2)}')
# Out:
#    support                itemsets
# 0      1.0          (Kidney Beans)
# 1      0.8    (Eggs, Kidney Beans)
# 2      0.8                  (Eggs)
# 3      0.6    (Kidney Beans, Milk)
# 4      0.6                  (Milk)
# 5      0.6   (Kidney Beans, Onion)
# 6      0.6                 (Onion)
# 7      0.6                (Yogurt)
# 8      0.6  (Yogurt, Kidney Beans)
# 9      0.6           (Eggs, Onion)
# Number of Itemsets: 47

# %% [markdown]
# **Task 3d**: Use the `apriori` function to list all itemsets up to size `3`. Sort the results in **ascending** order this time by their `support` value.

# %%
df_itemset_max_3 = # Add your code here
df_itemset_max_3 = # Add your code here for sorting the dataframe
display(df_itemset_max_3.head(10))
print(f'\nNumber of Itemsets: {len(df_itemset_max_3)}')
# Out:
#    support                       itemsets
# 0      0.2                        (Apple)
# 1      0.2           (Nutmeg, Eggs, Dill)
# 2      0.2     (Eggs, Kidney Beans, Dill)
# 3      0.2        (Unicorn, Yogurt, Corn)
# 4      0.2           (Yogurt, Corn, Milk)
# 5      0.2          (Unicorn, Corn, Milk)
# 6      0.2   (Yogurt, Kidney Beans, Corn)
# 7      0.2  (Unicorn, Kidney Beans, Corn)
# 8      0.2    (Kidney Beans, Corn, Onion)
# 9      0.2     (Kidney Beans, Corn, Milk)
# Number of Itemsets: 98

# %% [markdown]
# **Task 3e**: Use the `apriori` function to list all itemsets. Sort the results in **ascending** order this time by their `support` value.

# %%
df_itemset_max = # Add your code here
df_itemset_max = # Add your code here for sorting the dataframe
display(df_itemset_max.head(10))
print(f'\nNumber of Itemsets: {len(df_itemset_max)}')
# Out:
#    support                                itemsets
# 0      0.2                                 (Apple)
# 1      0.2      (Nutmeg, Eggs, Kidney Beans, Dill)
# 2      0.2           (Unicorn, Yogurt, Corn, Milk)
# 3      0.2   (Unicorn, Yogurt, Kidney Beans, Corn)
# 4      0.2      (Yogurt, Kidney Beans, Corn, Milk)
# 5      0.2     (Unicorn, Kidney Beans, Corn, Milk)
# 6      0.2  (Ice cream, Kidney Beans, Corn, Onion)
# 7      0.2       (Eggs, Kidney Beans, Corn, Onion)
# 8      0.2          (Eggs, Ice cream, Corn, Onion)
# 9      0.2   (Eggs, Kidney Beans, Corn, Ice cream)
# Number of Itemsets: 149

# %% [markdown]
# **Task 3f**: Calculate the length for each itemset computed above.

# %%
df_itemset_max['length'] = # Add your code here
df_itemset_max.head(10)
# Out:
#    support                                itemsets  length
# 0      0.2                                 (Apple)       1
# 1      0.2      (Nutmeg, Eggs, Kidney Beans, Dill)       4
# 2      0.2           (Unicorn, Yogurt, Corn, Milk)       4
# 3      0.2   (Unicorn, Yogurt, Kidney Beans, Corn)       4
# 4      0.2      (Yogurt, Kidney Beans, Corn, Milk)       4
# 5      0.2     (Unicorn, Kidney Beans, Corn, Milk)       4
# 6      0.2  (Ice cream, Kidney Beans, Corn, Onion)       4
# 7      0.2       (Eggs, Kidney Beans, Corn, Onion)       4
# 8      0.2          (Eggs, Ice cream, Corn, Onion)       4
# 9      0.2   (Eggs, Kidney Beans, Corn, Ice cream)       4

# %% [markdown]
# **Task 3g**: Group the itemsets by length and count them.

# %%
df_itemset_max.# Add your code here
# Out:
#         itemsets
# length
# 1             11
# 2             36
# 3             51
# 4             36
# 5             13
# 6              2

# %% [markdown]
# **Task 3h**: Use the `apriori` function to list all itemsets and with support value of at least `0.5`. Sort the results in **ascending** order by their `support` value.

# %%
df_itemset_max_h = # Add your code here
df_itemset_max_h = # Add your code here for sorting the dataframe
display(df_itemset_max_h)
print(f'\nNumber of Itemsets: {len(df_itemset_max_h)}')
# Out:
#     support                     itemsets
# 0       0.6                       (Milk)
# 1       0.6                      (Onion)
# 2       0.6                     (Yogurt)
# 3       0.6                (Eggs, Onion)
# 4       0.6         (Kidney Beans, Milk)
# 5       0.6        (Kidney Beans, Onion)
# 6       0.6       (Yogurt, Kidney Beans)
# 7       0.6  (Eggs, Kidney Beans, Onion)
# 8       0.8                       (Eggs)
# 9       0.8         (Eggs, Kidney Beans)
# 10      1.0               (Kidney Beans)
# Number of Itemsets: 11

# %% [markdown]
# ## Association Rule Mining

# %% [markdown]
# From [mlxtend > Association Rules > Overview](https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/) we have:
#
# Rule generation is a common task in the mining of frequent patterns. An association rule is an implication expression of the form $X→Y$, where $X$ and $Y$ are disjoint itemsets. A more concrete example based on consumer behaviour would be $\{Diapers\}→\{Beer\}$ suggesting that people who buy diapers are also likely to buy beer. To evaluate the "interest" of such an association rule, different metrics have been developed. The current implementation make use of the `confidence` and `lift` metrics.

# %% [markdown]
# **Metrics**
#
# - **Support**
#
# $$
# \text{support}(A→C)=\text{support}(A∪C), \quad \text{range:} [0,1]
# $$
#
# The support metric is defined for itemsets, not assocication rules. The table produced by the association rule mining algorithm contains three different support metrics: `antecedent support`, `consequent support`, and `support`. Here, `antecedent support` computes the proportion of transactions that contain the antecedent $A$, and `consequent support` computes the support for the itemset of the consequent $C$. The `support` metric then computes the support of the combined itemset $A ∪ C$ -- note that `support` depends on `antecedent support` and `consequent support` via min(`antecedent support`, `consequent support`).
#
# Typically, support is used to measure the abundance or frequency (often interpreted as significance or importance) of an itemset in a database. We refer to an itemset as a "frequent itemset" if you support is larger than a specified minimum-support threshold. Note that in general, due to the downward closure property, all subsets of a frequent itemset are also frequent.
#
# - **Confidence**'
#
# $$\text{confidence}(A→C)=\frac{\text{support}(A→C)}{\text{support}(A)},\quad \text{range:} [0,1]$$
#
# The confidence of a rule A->C is the probability of seeing the consequent in a transaction given that it also contains the antecedent. Note that the metric is not symmetric or directed; for instance, the confidence for A->C is different than the confidence for C->A. The confidence is 1 (maximal) for a rule A->C if the consequent and antecedent always occur together.
#
# - **Lift**:
#
# $$\text{lift}(A→C)=\frac{\text{confidence}(A→C)}{\text{support}(C)},\quad \text{range:} [0,∞]$$
#
# The lift metric is commonly used to measure how much more often the antecedent and consequent of a rule $A->C$ occur together than we would expect if they were statistically independent. If $A$ and $C$ are independent, the Lift score will be exactly $1$.
#
# - **Leverage**:
#
# $$\text{levarage}(A→C)=\text{support}(A→C)−\text{support}(A)×\text{support}(C),\quad \text{range:} [−1,1]$$
#
# The leverage computes the difference between the observed frequency of $A$ and $C$ appearing together and the frequency that would be expected if $A$ and $C$ were independent. An leverage value of $0$ indicates independence.
#
# - **Conviction**:
#
# $$\text{conviction}(A→C)=\frac{1−\text{support}(C)}{1−\text{confidence}(A→C)}, \quad \text{range:} [0,∞]$$
#
# A high conviction value means that the consequent is highly depending on the antecedent. For instance, in the case of a perfect confidence score, the denominator becomes $0$ (due to $1 - 1$) for which the conviction score is defined as 'inf'. Similar to Lift, if items are independent, the conviction is $1$.

# %% [markdown]
# ## Task 4: Mining Rules

# %% [markdown]
# **Recap**

# %%
df_itemset_max
display(df_itemset_max.head(10))
print(f'\nNumber of Itemsets: {len(df_itemset_max)}')
# Out:
#    support                                itemsets  length
# 0      0.2                                 (Apple)       1
# 1      0.2      (Nutmeg, Eggs, Kidney Beans, Dill)       4
# 2      0.2           (Unicorn, Yogurt, Corn, Milk)       4
# 3      0.2   (Unicorn, Yogurt, Kidney Beans, Corn)       4
# 4      0.2      (Yogurt, Kidney Beans, Corn, Milk)       4
# 5      0.2     (Unicorn, Kidney Beans, Corn, Milk)       4
# 6      0.2  (Ice cream, Kidney Beans, Corn, Onion)       4
# 7      0.2       (Eggs, Kidney Beans, Corn, Onion)       4
# 8      0.2          (Eggs, Ice cream, Corn, Onion)       4
# 9      0.2   (Eggs, Kidney Beans, Corn, Ice cream)       4
# Number of Itemsets: 149

# %%
df_itemset_max.# Add your code here
# Out:
#         itemsets
# length
# 1             11
# 2             36
# 3             51
# 4             36
# 5             13
# 6              2

# %% [markdown]
# **Task 4a**: Use the `association_rules` function to generate a DataFrame containing **all** rules that can be extracted from the given data sample.
#
# Tip: Check the [documentation for this function](https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/#api). You will need to set three arguments `min_support`, `use_colnames` and `max_len`.
#
# Tip: To include all frequent itemsets, ensure to provide a `min_support` small enough, approaching zero.

# %%
rules_max_h = # Add your code here
display(rules_max_h.head(10))
print(f'\nNumber of Rules: {len(rules_max_h)}')
# Out:
#                     antecedents             consequents  ...  leverage  conviction
# 0  (Eggs, Kidney Beans, Nutmeg)                  (Dill)  ...      0.12    1.600000
# 1          (Dill, Eggs, Nutmeg)          (Kidney Beans)  ...      0.00         inf
# 2  (Dill, Kidney Beans, Nutmeg)                  (Eggs)  ...      0.04         inf
# 3    (Eggs, Kidney Beans, Dill)                (Nutmeg)  ...      0.12         inf
# 4                (Eggs, Nutmeg)    (Kidney Beans, Dill)  ...      0.12    1.600000
# 5        (Kidney Beans, Nutmeg)            (Eggs, Dill)  ...      0.12    1.600000
# 6                (Dill, Nutmeg)    (Eggs, Kidney Beans)  ...      0.04         inf
# 7          (Eggs, Kidney Beans)          (Dill, Nutmeg)  ...      0.04    1.066667
# 8                  (Eggs, Dill)  (Kidney Beans, Nutmeg)  ...      0.12         inf
# 9          (Kidney Beans, Dill)          (Eggs, Nutmeg)  ...      0.12         inf
#
# [10 rows x 9 columns]
# Number of Rules: 1396

# %% [markdown]
# **Task 4b**: Show the 10 most *confident* rules.

# %%
rules_max_h.# Add your code here
# Out:
#                            antecedents  ... conviction
# 0      (Ice cream, Kidney Beans, Corn)  ...        inf
# 1               (Dill, Yogurt, Nutmeg)  ...        inf
# 2                       (Dill, Nutmeg)  ...        inf
# 3         (Yogurt, Kidney Beans, Dill)  ...        inf
# 4         (Dill, Kidney Beans, Nutmeg)  ...        inf
# 5  (Yogurt, Milk, Kidney Beans, Onion)  ...        inf
# 6   (Eggs, Yogurt, Kidney Beans, Milk)  ...        inf
# 7          (Eggs, Yogurt, Milk, Onion)  ...        inf
# 8    (Eggs, Milk, Kidney Beans, Onion)  ...        inf
# 9                               (Dill)  ...        inf
#
# [10 rows x 9 columns]

# %% [markdown]
# **Task 4c**: Show the 10 least *confident* rules.

# %%
rules_max_h.# Add your code here
# Out:
#       antecedents              consequents  ...  leverage  conviction
# 0  (Kidney Beans)            (Eggs, Apple)  ...       0.0         1.0
# 1  (Kidney Beans)      (Onion, Eggs, Dill)  ...       0.0         1.0
# 2  (Kidney Beans)                (Unicorn)  ...       0.0         1.0
# 3  (Kidney Beans)            (Onion, Dill)  ...       0.0         1.0
# 4  (Kidney Beans)                   (Dill)  ...       0.0         1.0
# 5  (Kidney Beans)      (Eggs, Apple, Milk)  ...       0.0         1.0
# 6  (Kidney Beans)              (Ice cream)  ...       0.0         1.0
# 7  (Kidney Beans)  (Eggs, Corn, Ice cream)  ...       0.0         1.0
# 8  (Kidney Beans)             (Corn, Milk)  ...       0.0         1.0
# 9  (Kidney Beans)                  (Apple)  ...       0.0         1.0
#
# [10 rows x 9 columns]

# %% [markdown]
# **Task 4d**: Show the 10 most *convicted* rules that have the largest `consequents` sets and the largest `antecedents` sets.

# %%
rules_max_h['antecedents len'] = # Add your code here
rules_max_h['consequents len'] = # Add your code here
rules_max_h.# Add your code here for sorting the dataframe
# Out:
#             antecedents  ... consequents len
# 0                (Dill)  ...               5
# 1        (Yogurt, Dill)  ...               4
# 2  (Kidney Beans, Dill)  ...               4
# 3         (Dill, Onion)  ...               4
# 4          (Eggs, Dill)  ...               4
# 5        (Nutmeg, Dill)  ...               4
# 6         (Milk, Onion)  ...               4
# 7        (Nutmeg, Milk)  ...               4
# 8                (Dill)  ...               4
# 9                (Dill)  ...               4
#
# [10 rows x 11 columns]

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Task 5

# %%
df_rules = rules_max_h.copy()
df_rules['rule'] = df_rules.apply(lambda x: f"{set(x['antecedents'])} -> {set(x['consequents'])}", axis=1)
df_rules['rule len'] = df_rules.apply(lambda x: x['antecedents len'] + x['consequents len'], axis=1)
df_rules.head()
# Out:
#                     antecedents  ... rule len
# 0  (Eggs, Kidney Beans, Nutmeg)  ...        4
# 1          (Dill, Eggs, Nutmeg)  ...        4
# 2  (Dill, Kidney Beans, Nutmeg)  ...        4
# 3    (Eggs, Kidney Beans, Dill)  ...        4
# 4                (Eggs, Nutmeg)  ...        4
#
# [5 rows x 13 columns]

# %%
len(df_rules)
# Out:
# 1396

# %% [markdown]
# **Task 5a**: Produce a scatter plot of `support` vs `confidence`.
#
# Tip: use `backend='plotly'` for showing an interactive plot. Show the `rule` property on `hover_data`.

# %%
# Add your code here
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Task 5b**: Produce a scatter plot of `leverage` vs `confidence`.

# %%
# Add your code here
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Task 5c**: Produce a scatter plot of `leverage` vs `confidence`. Improve the visualization using `support` and `conviction` as size and color of the markers, respectively.

# %%
# Add your code here
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
